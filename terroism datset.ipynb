# %% [markdown]
# ## Data Science Intern - LetsGrowMore
#
# ### By : Achyut Tiwari
#
# ## TASK 1 : INTERMEDIATE LEVEL
#
# ### Exploratory Data Analysis - Terrorism
#
# ### As a security/defense analyst, we have to find out the hot zone of terrorism.
#
# Dataset link: https://bit.ly/2TK5Xn5

# %% [markdown]
# ## Importing the Libraries :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %% [markdown]
# ## Importing the Dataset :

# %%
data = pd.read_csv('globalterrorismdb_0718dist.csv')
# Out:
# C:\Users\achyut\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data.value_counts
# Out:
# <bound method DataFrame.value_counts of              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
# ...

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
data.isnull().any()
# Out:
# eventid       False
# iyear         False
# imonth        False
# iday          False
# approxdate     True
#               ...
# INT_LOG       False
# INT_IDEO      False
# INT_MISC      False
# INT_ANY       False
# related        True
# Length: 135, dtype: bool

# %%
countries_with_most_terrorism = data.country_txt.value_counts().head(10)
countries = list(countries_with_most_terrorism.index)

# %% [markdown]
# ## VISUALIZING THE DATA BY USING BAR GRAPH :

# %%
fig, ax = plt.subplots(figsize=(14,5))
ax.bar(countries_with_most_terrorism.index,countries_with_most_terrorism.values,color='r')
plt.title('Countries with most terrorism')
plt.xlabel('Country')
plt.ylabel('Values')
plt.show()

# %%
 countries_with_most_terrorism =data.country_txt.value_counts().head(10).transpose().plot(figsize=(15,10))

# %%
print(countries)
# Out:
# ['Iraq', 'Pakistan', 'Afghanistan', 'India', 'Colombia', 'Philippines', 'Peru', 'El Salvador', 'United Kingdom', 'Turkey']

# %%
sns.displot(data,x='country',kind='kde',fill='tree',palette='colorblind',color='orange')
sns.set_style("darkgrid")

# %%
sns.displot(data,x='iyear',kind='hist',palette='colorblind',color='#CB4335')
plt.style.use("ggplot")

# %% [markdown]
# ## Terrorist Activity :

# %%
year = data.iyear.value_counts().head(5)
plt.figure(figsize=(12,6))
plt.bar(year.index,year.values,color='#D68910')
plt.title("Years with most number of terrorist activity")
plt.xlabel("Year")
plt.ylabel("Values")
plt.show()
plt.style.use("ggplot")

# %% [markdown]
# #### 2014 was recorded to have most number of terrorist attacks.

# %%
target = data['targtype1_txt'].value_counts().head(10)
fig,ax = plt.subplots(figsize=(16,6))
ax.bar(target.index,target.values,color='#CD5C5C')
plt.title('Type of Targets')
plt.xlabel("Targets")
plt.ylabel("Values")
plt.show()

# %% [markdown]
#  ### list of the Private Citizens and property targeted the most.

# %%
weapon_type = data['weaptype1_txt'].value_counts().head(6)
fig,ax = plt.subplots(figsize=(16,6))
ax.bar(weapon_type.index,weapon_type.values,color='#DFFF00')
plt.title('Type of Attacks')
plt.xlabel("Attacks")
plt.ylabel("Values")
plt.show()

# %%
sns.displot(data,x='iyear',kind='kde',fill='tree',palette='colorblind',color='blue')

# %%
religious_target = data[data['targtype1_txt']=='Religious Figures/Institutions']
plt.figure(figsize=(14,6))
plt.bar(religious_target['country_txt'].value_counts().head().index,religious_target['country_txt'].value_counts().head().values,color='#008080')
plt.title("Countries with most terrorism on religious figures")
plt.xlabel("Country")
plt.ylabel("Values")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Iraq is the country with most terrorism due to religious reasons.

# %%
cities_with_most_terrorism = data.city.value_counts().head(10)
cities = list(cities_with_most_terrorism.index)
cities_with_most_terrorism
fig,ax = plt.subplots(figsize=(16,6))
plt.style.use('default')
ax.bar(cities_with_most_terrorism.index,cities_with_most_terrorism.values,color='#000080')
plt.title('Countries with most terrorism')
plt.xlabel('Country')
plt.ylabel('Values')
plt.show()

# %%
year = data['iyear'].unique()
years_count = data['iyear'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (16,6))
sns.barplot(x = year,
           y = years_count,
           palette = "pastel")
plt.xticks(rotation = 50)
plt.xlabel('Attacking Year',fontsize=20)
plt.ylabel('Number of Attacks Each Year',fontsize=20)
plt.title('Attacks In Years',fontsize=20)
plt.show()

# %%
plt.subplots(figsize=(18,8))
sns.countplot(data["iyear"],order=data['iyear'].value_counts().index,palette="bright")
plt.xticks(rotation=90)
plt.xlabel("Attacktype",fontsize=15)
plt.ylabel("count",fontsize=15)
plt.title("Attack per year",fontsize=20)
plt.show()
# Out:
# C:\Users\achyut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data['country'].value_counts().to_frame().head(10).plot(kind='bar',color='#800000',figsize=(20,10))
plt.title("Top 10 terrorist group attack",fontsize=20)
plt.xlabel("terrorist group count",fontsize=15)
plt.ylabel("Attack number",fontsize=15)
plt.show()

# %% [markdown]
# ## CONCLUSION :
#
# Following are the Conclusion after Analysis :
#
#
# 1.Iraq is Country with the most attacks.
#
# 2.Private Citizens & Property Regions were most Attack.
#
# 3.2014 is Year with the most attacks.
#
# 4.Month with the most attacks: 5
#
# 5.Most Attack Types: Bombing/Explosion
#
# 6.Baghdad is City with the most attacks.
